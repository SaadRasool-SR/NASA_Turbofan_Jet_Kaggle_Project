# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
index_names = ['engine', 'cycle']
setting_names = ['setting_1', 'setting_2', 'setting_3']
sensor_names = ['sensor_{}'.format(i) for i in range(1,22)] 
col_names = index_names + setting_names + sensor_names

# %%
train_1 = pd.read_csv('train_FD001.txt', sep='\s+', header=None, names=col_names)
test_1 = pd.read_csv('test_FD001.txt', sep='\s+', header=None, names=col_names)
rul_1 = pd.read_csv('RUL_FD001.txt', sep='\s+', header=None, names=['RUL'])

train_2 = pd.read_csv('train_FD002.txt', sep='\s+', header=None, names=col_names)
test_2 = pd.read_csv('test_FD002.txt', sep='\s+', header=None, names=col_names)
rul_2 = pd.read_csv('RUL_FD002.txt', sep='\s+', header=None, names=['RUL'])

train_3 = pd.read_csv('train_FD003.txt', sep='\s+', header=None, names=col_names)
test_3 = pd.read_csv('test_FD003.txt', sep='\s+', header=None, names=col_names)
rul_3 = pd.read_csv('RUL_FD003.txt', sep='\s+', header=None, names=['RUL'])

train_4 = pd.read_csv('train_FD004.txt', sep='\s+', header=None, names=col_names)
test_4 = pd.read_csv('test_FD004.txt', sep='\s+', header=None, names=col_names)
rul_4 = pd.read_csv('RUL_FD004.txt', sep='\s+', header=None, names=['RUL'])

# %%
train_1.shape, test_1.shape, rul_1.shape
# Out:
# ((20631, 26), (13096, 26), (100, 1))

# %%
train_1.head()
# Out:
#    engine  cycle  setting_1  setting_2  setting_3  sensor_1  sensor_2  \
# 0       1      1    -0.0007    -0.0004      100.0    518.67    641.82
# 1       1      2     0.0019    -0.0003      100.0    518.67    642.15
# 2       1      3    -0.0043     0.0003      100.0    518.67    642.35
# 3       1      4     0.0007     0.0000      100.0    518.67    642.35
# 4       1      5    -0.0019    -0.0002      100.0    518.67    642.37
#
#    sensor_3  sensor_4  sensor_5  ...  sensor_12  sensor_13  sensor_14  \
# 0   1589.70   1400.60     14.62  ...     521.66    2388.02    8138.62
# 1   1591.82   1403.14     14.62  ...     522.28    2388.07    8131.49
# 2   1587.99   1404.20     14.62  ...     522.42    2388.03    8133.23
# 3   1582.79   1401.87     14.62  ...     522.86    2388.08    8133.83
# 4   1582.85   1406.22     14.62  ...     522.19    2388.04    8133.80
#
#    sensor_15  sensor_16  sensor_17  sensor_18  sensor_19  sensor_20  sensor_21
# ...

# %%
def cal_rul(df):
    df_g = df.groupby('engine')['cycle'].max()
    df_g = df_g.to_frame().reset_index()
    df_g.columns = ['engine', 'max_cycle']
    df_result = df.merge(df_g, on='engine', how='left')
    df_result['RUL'] = df_result['max_cycle'] - df_result['cycle']
    return df_result

# %%
train_1 = cal_rul(train_1)
train_1
# Out:
#        engine  cycle  setting_1  setting_2  setting_3  sensor_1  sensor_2  \
# 0           1      1    -0.0007    -0.0004      100.0    518.67    641.82
# 1           1      2     0.0019    -0.0003      100.0    518.67    642.15
# 2           1      3    -0.0043     0.0003      100.0    518.67    642.35
# 3           1      4     0.0007     0.0000      100.0    518.67    642.35
# 4           1      5    -0.0019    -0.0002      100.0    518.67    642.37
# ...       ...    ...        ...        ...        ...       ...       ...
# 20626     100    196    -0.0004    -0.0003      100.0    518.67    643.49
# 20627     100    197    -0.0016    -0.0005      100.0    518.67    643.54
# 20628     100    198     0.0004     0.0000      100.0    518.67    643.42
# 20629     100    199    -0.0011     0.0003      100.0    518.67    643.23
# 20630     100    200    -0.0032    -0.0005      100.0    518.67    643.85
#
#        sensor_3  sensor_4  sensor_5  ...  sensor_14  sensor_15  sensor_16  \
# ...

# %%
test_1 = cal_rul(test_1)
test_1
# Out:
#        engine  cycle  setting_1  setting_2  setting_3  sensor_1  sensor_2  \
# 0           1      1     0.0023     0.0003      100.0    518.67    643.02
# 1           1      2    -0.0027    -0.0003      100.0    518.67    641.71
# 2           1      3     0.0003     0.0001      100.0    518.67    642.46
# 3           1      4     0.0042     0.0000      100.0    518.67    642.44
# 4           1      5     0.0014     0.0000      100.0    518.67    642.51
# ...       ...    ...        ...        ...        ...       ...       ...
# 13091     100    194     0.0049     0.0000      100.0    518.67    643.24
# 13092     100    195    -0.0011    -0.0001      100.0    518.67    643.22
# 13093     100    196    -0.0006    -0.0003      100.0    518.67    643.44
# 13094     100    197    -0.0038     0.0001      100.0    518.67    643.26
# 13095     100    198     0.0013     0.0003      100.0    518.67    642.95
#
#        sensor_3  sensor_4  sensor_5  ...  sensor_14  sensor_15  sensor_16  \
# ...

# %%
train_1.describe().transpose()
# Out:
#              count         mean           std        min        25%  \
# engine     20631.0    51.506568  2.922763e+01     1.0000    26.0000
# cycle      20631.0   108.807862  6.888099e+01     1.0000    52.0000
# setting_1  20631.0    -0.000009  2.187313e-03    -0.0087    -0.0015
# setting_2  20631.0     0.000002  2.930621e-04    -0.0006    -0.0002
# setting_3  20631.0   100.000000  0.000000e+00   100.0000   100.0000
# sensor_1   20631.0   518.670000  0.000000e+00   518.6700   518.6700
# sensor_2   20631.0   642.680934  5.000533e-01   641.2100   642.3250
# sensor_3   20631.0  1590.523119  6.131150e+00  1571.0400  1586.2600
# sensor_4   20631.0  1408.933782  9.000605e+00  1382.2500  1402.3600
# sensor_5   20631.0    14.620000  1.776400e-15    14.6200    14.6200
# sensor_6   20631.0    21.609803  1.388985e-03    21.6000    21.6100
# sensor_7   20631.0   553.367711  8.850923e-01   549.8500   552.8100
# sensor_8   20631.0  2388.096652  7.098548e-02  2387.9000  2388.0500
# ...

# %%
plt.plot(train_1['RUL'], train_1['sensor_1'])
plt.show()

# %% [markdown]
# Setting 3 and Sensor 1, 5, 10, 16, 18 and 19 did not change with circle, thus they can be removed.

# %%
train_1.drop(['sensor_1', 'sensor_5','sensor_10','sensor_16','sensor_18','sensor_19','setting_3'], axis=1, inplace=True)
train_1
# Out:
#        engine  cycle  setting_1  setting_2  sensor_2  sensor_3  sensor_4  \
# 0           1      1    -0.0007    -0.0004    641.82   1589.70   1400.60
# 1           1      2     0.0019    -0.0003    642.15   1591.82   1403.14
# 2           1      3    -0.0043     0.0003    642.35   1587.99   1404.20
# 3           1      4     0.0007     0.0000    642.35   1582.79   1401.87
# 4           1      5    -0.0019    -0.0002    642.37   1582.85   1406.22
# ...       ...    ...        ...        ...       ...       ...       ...
# 20626     100    196    -0.0004    -0.0003    643.49   1597.98   1428.63
# 20627     100    197    -0.0016    -0.0005    643.54   1604.50   1433.58
# 20628     100    198     0.0004     0.0000    643.42   1602.46   1428.18
# 20629     100    199    -0.0011     0.0003    643.23   1605.26   1426.53
# 20630     100    200    -0.0032    -0.0005    643.85   1600.38   1432.14
#
#        sensor_6  sensor_7  sensor_8  ...  sensor_11  sensor_12  sensor_13  \
# ...

# %%
plt.figure(figsize=(12,12))
mask = np.triu(np.ones_like(train_1.corr()), k=1)
sns.heatmap(train_1.corr(), annot=True, cmap='RdYlBu', mask=mask, linewidths=0.5,
            vmin = -1.0, vmax=1.0, square=True, linecolor='white', annot_kws={'size':7},
            cbar_kws={'shrink':0.8})
plt.title('Train_1', fontsize=16)
plt.show()

# %%
plt.figure(figsize=(12,12))
mask = np.triu(np.ones_like(train_1.loc[:,'sensor_2':'sensor_21'].corr()), k=1)
sns.heatmap(train_1.loc[:,'sensor_2':'sensor_21'].corr(), annot=True, cmap='coolwarm', mask=mask, linewidths=0.5,
            vmin = -1.0, vmax=1.0, square=True, linecolor='white', annot_kws={'size':7},
            cbar_kws={'shrink':0.8})
plt.title('Sensors of Train_1', fontsize=16)
plt.show()
